# %%
# import the necessary packages
import numpy as np
import argparse
import imutils
import cv2


from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("gel_sample.png")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img)

# %%
plt.imshow(gray)

# %%
sum_rows = np.sum(gray,axis=0)
plt.plot(sum_rows)

# %%
from scipy import signal

#generate junk data (numpy 1D arr)
xs = t1 #np.arange(0, np.pi, 0.05)
data = sum_rows #np.sin(xs)

# maxima : use builtin function to find (max) peaks
max_peakind = signal.find_peaks_cwt(data, np.arange(1,10))

# inverse  (in order to find minima)
inv_data = 1/data
# minima : use builtin function fo find (min) peaks (use inversed data)
min_peakind = signal.find_peaks_cwt(inv_data, np.arange(1,10))

#show results
print ("maxima",  data[max_peakind])
print ("minima",  data[min_peakind])

plot(x,data)
plot(x[max_peakind], data[max_peakind], "o", label="min")
plot(x[min_peakind], data[min_peakind], "o", label="max")
legend()
show()
# Out:
# maxima [14433 18354 21287 22183 21928 22531 22270 22273 21939 22091 15834]
# minima [14606 14557 18007 21213 18718 19736 21590 19827 19842 18870 22363 15834]

# %%
import matplotlib.pyplot as plt
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks
import numpy as np

peaks, _ = find_peaks(sum_rows, height=0)
plt.plot(sum_rows)
plt.plot(peaks, sum_rows[peaks], "x")
plt.plot(np.zeros_like(sum_rows), "--", color="gray")
plt.show()


peaks, _ = find_peaks(sum_rows, distance=20)
# difference between peaks is >= 150
print(np.diff(peaks))
# prints [186 180 177 171 177 169 167 164 158 162 172]

plt.plot(sum_rows)
plt.plot(peaks, sum_rows[peaks], "x")
plt.show()
# Out:
# [25 29 35 30 20 30 20 26 21 20]
